# %%
import pandas as pd

# %%
datafile = 'experimental_data/hogan_2025/hogan_50.pkl'

df = pd.read_pickle(datafile)

print(df[0:5])
# Out:
#    index         k       Phi    ustar       U10       Wdir   kn
# 0     50  0.010233  0.620735  0.25141  7.668248  221.40846  1.2
# 1     50  0.010471  0.590345  0.25141  7.668248  221.40846  1.2
# 2     50  0.010715  0.561443  0.25141  7.668248  221.40846  1.2
# 3     50  0.010965  0.533956  0.25141  7.668248  221.40846  1.2
# 4     50  0.011220  0.507815  0.25141  7.668248  221.40846  1.2
